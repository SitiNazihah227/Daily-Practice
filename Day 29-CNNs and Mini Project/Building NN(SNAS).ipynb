# %% [markdown]
# **01/01/2026**

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# ...
# Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl (331.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#tensorflow is from 

import tensorflow as tf
# Out:
# c:\Users\user\Desktop\AI & ML Class\Daily-Practice\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# c:\Users\user\Desktop\AI & ML Class\Daily-Practice\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.9118 - loss: 0.3031
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9567 - loss: 0.1454
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9668 - loss: 0.1089
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9719 - loss: 0.0901
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9766 - loss: 0.0731
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9774 - loss: 0.0733
# [0.07334091514348984, 0.977400004863739]

# %%
# pip freeze > requirement.txt
#SNAS: can run the pip freeze requirement above in the environment that you want to collect all the import modules so that we can install it into the new environment
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install -r requirement.txt
#SNAS: run above syntax to install all the modules file requirement into the new environment
# Out:
# ...
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl.metadata (7.5 kB)
# ...
#   Using cached arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# ...
#   Using cached bokeh-3.8.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# ...
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# ...
