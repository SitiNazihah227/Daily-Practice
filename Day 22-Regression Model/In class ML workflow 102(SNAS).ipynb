# %% [markdown]
# **23/12/2025**

# %% [markdown]
# ### ML workflow:
#
# 1. **Problem Scoping**
# 2. **Data Acquisition**
# 3. **EDA**
#     a. Clean data
#     b. Visualise data (you already learned EDA / cleaning).
#
# 4. **Choose a model** – e.g., Decision Tree for classification.
#
# 5. **Train**
#     a. Train/Test split.
#     b. Fit the model on training data.
#
# 6. **Test**
#     a. Make predictions on test data.
#     b. Compute performance (accuracy, etc.).
#     c. Reiterate based on performance

# %% [markdown]
# **Predict House Prices based on house parameters**
#
# 1. Predict the house prices based on various housing parameters.
#     - the problem is worth solving, because real estate professionals often need help in evaluating the prices of properties.
#
# 2. Data acquisition:
#     - use the inbuilt sci-kit learn dataset
#
# 3. EDA
#     - clean dataset - it is clean already - but still just recall a bit about cleaning techniques
#     - Visualize a little as well
#
# 4. Choose a model:
#     - Look into data, and we infer that it is a Regression Problem (because prices are a continous value)
#     - Linear Regression (we are using it here because it is a very simple model)
#     - *Next iteration, Logistic Regression (we will observe this model too. It works on classification problems too)*
#
# 5. Training
#     - Train-test split of 8:2 - 80% data for training
#     - Fit data into the model, model learns the patterns in data
#
# 6. Testing
#     - Make predictions
#     - Observe performance using evaluation metrics
#     - Regression evaluation metrics - R2 score and Mean Absolute Error
#
# 7. Improvement
#     - Reiterate

# %% [markdown]
# Resources for the notebook:
#
# - [Scikit Learn Dataset List](https://scikit-learn.org/stable/datasets/real_world.html)

# %% [markdown]
# ## Step1: Problem Scoping
# - write about it
#
# ## Step 2: Data Acquisition

# %% [markdown]
# - [Kaggle California Housing Dataset Link](https://www.kaggle.com/datasets/camnugent/california-housing-prices)

# %% [markdown]
# ##### a very quick way of getting data from kaggle
#
# ```python
# # Install dependencies as needed:
# # pip install kagglehub[pandas-datasets]
# import kagglehub
# from kagglehub import KaggleDatasetAdapter
#
# # Set the path to the file you'd like to load
# file_path = ""
#
# # Load the latest version
# df = kagglehub.load_dataset(
#   KaggleDatasetAdapter.PANDAS,
#   "camnugent/california-housing-prices",
#   file_path,
#   # Provide any additional arguments like
#   # sql_query or pandas_kwargs. See the
#   # documenation for more information:
#   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas

# %% [markdown]
# **Identification of price  based on flower physical measurements**
#
# 1. Predict the species of iris flower, based on flower physical measurement.
#     - the problem is worth solving, because the flower species are very hard to identify, even for experts.
#
# 2. Data acquisition:
#     - use the inbuilt sci-kit learn dataset
#
# 3. EDA
#     - clean dataset - it is clean already - but still just recall a bit about cleaning techniques
#     - Visualize a little as well
#
# 4. Choose a model:
#     - Look into data, and we infer that it is a Classification Problem
#     - Linear Regression (we are using it here because it is a very simple model)
#     - Next iteration, Logistic Regression

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import fetch_california_housing

import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learniing
from sklearn.linear_model import LinearRegression, LogisticRegression
# Model Training
from sklearn.model_selection import train_test_split
# Model Evaluation
from sklearn.metrics import mean_absolute_error, r2_score

# %%
housing_data = fetch_california_housing()

housing_data.feature_names

# Input features
df = pd.DataFrame(housing_data.data, columns = housing_data.feature_names)

# Target feature
df['Price'] = housing_data.target

# Check the dataset
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 housing_data = fetch_california_housing()
#       3 housing_data.feature_names
#       5 # Input features
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...

# %%
#SNAS: sir trying to troubleshoot my problem not able to read fetch_california_housing data
house_prices = fetch_openml(name='house_prices', as_frame=True)

# %%
#SNAS: sir trying to troubleshoot my problem not able to read fetch_california_housing data
house_prices.data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df = pd.read_csv("housing.csv")
df.head() 
#c:\Users\user\Desktop\AI & ML Class\Day#22 23122025\housing.csv\housing.csv

#SNAS: alternate way to download dataset since sklearn not working for my Visual Code
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#SNAS: my approach on fetching dataset using pandas

feature_names = df.drop("median_house_value", axis=1).columns.tolist()

from sklearn.utils import Bunch

housing_data = Bunch(
    data=df[feature_names].values,
    target=df["median_house_value"].values,
    feature_names=feature_names
)

# %%
housing_data.feature_names
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity']

# %%
# input features
df = pd.DataFrame(
    housing_data.data,
    columns=housing_data.feature_names
)

# target feature
df["Price"] = housing_data.target

# check dataset
df.head()
# Out:
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -122.23    37.88               41.0       880.0          129.0      322.0
# 1   -122.22    37.86               21.0      7099.0         1106.0     2401.0
# 2   -122.24    37.85               52.0      1467.0          190.0      496.0
# 3   -122.25    37.85               52.0      1274.0          235.0      558.0
# 4   -122.25    37.85               52.0      1627.0          280.0      565.0
#
#   households median_income ocean_proximity     Price
# 0      126.0        8.3252        NEAR BAY  452600.0
# 1     1138.0        8.3014        NEAR BAY  358500.0
# 2      177.0        7.2574        NEAR BAY  352100.0
# 3      219.0        5.6431        NEAR BAY  341300.0
# 4      259.0        3.8462        NEAR BAY  342200.0

# %%
#SNAS: sir using sklearn to download the dataset however it doesn't work on my computer. please refer to sir's note

# %%
#SNAS: class code as below but the dataset doesn't want to work on my computer

housing_data = fetch_california_housing()

housing_data.feature_names

# Input features
df = pd.DataFrame(housing_data.data, columns = housing_data.feature_names)

# Target feature
df['Price'] = housing_data.target

# Check the dataset
df.head()

# %% [markdown]
# #### **About the Dataset:**
# - `MedInc` - Median income of the households in the block - 10s thousands
# - `HouseAge` - The age of house - years
# - `AveRooms` - # of Rooms
# - `AveBedrms` - # of Bed Rooms
# - `Population` - # of people within the block of the property
# - `AveOccup` - # of people living in the housing
# - `Latitude` - Location cordinates Latitude
# - `Longitude` - Location cordinates Longitude
# - `HousePrice` - Will mention the price of the property - 10s thousands

# %% [markdown]
# > Exercise:
# - turn the price columns into 10 thousand units, i.e. multiply all records with 10 thousand
# - turn them back to ones units

# %% [markdown]
# ## Step 3: EDA (Exploratory Data Analysis)
# - Explore the data
# - Clean the data
# - Visualizations

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  object
#  1   latitude            20640 non-null  object
#  2   housing_median_age  20640 non-null  object
#  3   total_rooms         20640 non-null  object
#  4   total_bedrooms      20433 non-null  object
#  5   population          20640 non-null  object
#  6   households          20640 non-null  object
#  7   median_income       20640 non-null  object
#  8   ocean_proximity     20640 non-null  object
#  9   Price               20640 non-null  float64
# dtypes: float64(1), object(9)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#                Price
# count   20640.000000
# mean   206855.816909
# std    115395.615874
# min     14999.000000
# 25%    119600.000000
# 50%    179700.000000
# 75%    264725.000000
# max    500001.000000

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# Price                   0
# dtype: int64

# %% [markdown]
# **No cleaning needed. Already cleanded**

# %% [markdown]
# **Visualizations**

# %% [markdown]
# 1. Specify the defaults for the visualization

# %%
#SNAS: we need to check whether the data has outliers

plt.hist(df['Price'], bins= 30)

# important stuff you should always keep for visualizations
plt.title('Distribution of House Price')
plt.xlabel('Price of Houses')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

# %%
#SNAS: since my code using Pandas to import, it included non-numerical columns & data as well. if using sklearn, it drops non-numerical data.
#SNAS: so I need to drop non-numerical data before visualization in heatmap

# %%
# exploring 
# i am trying to know about the important features of the dataset
plt.figure(figsize=(12,4))
sns.heatmap(
    df.drop("ocean_proximity", axis=1).corr(),  #dropping column 'ocean_proximity' manually
    annot=True
)#SNAS: my heatmap since I acquired data using Pandas
#sns.heatmap(df.corr(), annot=True) #SNAS: sir's heatmap as sklearn did not include non-numerical data
plt.title('Heatmap to Check Relationships')
plt.show()  #SNAS: this is use for script, but can use here so that some feature not shown
#SNAS: from the heatmap we can see teh relation of other factors (columns) with price

# %%
#SNAS: 
plt.scatter(df['median_income'], df['Price'])
plt.title('Median Income vs. House Price')
plt.xlabel('Median Income')
plt.ylabel('House Price')
plt.show()

# %% [markdown]
# **Insights**
# - insights needed for machine learning later

# %% [markdown]
# **Exercise**
# - to make better visualizations
# - get more insights and record them
# - to create all visualization in a single plot, using subplot and figsize to manipulate visualization

# %%
#pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 4: Choosing the Model
#
# - Choosing Linear Regression

# %% [markdown]
# - Linear Regression
# - How it works

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 5: Training
#
# - Train Test Split of data
# - Fit the model with Data

# %%
# split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
df.head()
# Out:
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -122.23    37.88               41.0       880.0          129.0      322.0
# 1   -122.22    37.86               21.0      7099.0         1106.0     2401.0
# 2   -122.24    37.85               52.0      1467.0          190.0      496.0
# 3   -122.25    37.85               52.0      1274.0          235.0      558.0
# 4   -122.25    37.85               52.0      1627.0          280.0      565.0
#
#   households median_income ocean_proximity     Price
# 0      126.0        8.3252        NEAR BAY  452600.0
# 1     1138.0        8.3014        NEAR BAY  358500.0
# 2      177.0        7.2574        NEAR BAY  352100.0
# 3      219.0        5.6431        NEAR BAY  341300.0
# 4      259.0        3.8462        NEAR BAY  342200.0

# %%
# input features
X = df[['longitude', 'latitude', 'housing_median_age','total_rooms', 'population', 'households', 'median_income']] #SNAS: had to exclude total_bedrooms as it is having NaN value & oceon_proximity because it is string
# X = df[['MedInc',	'HouseAge',	'AveRooms'	,'Latitude']]

# target
y = df['Price']

# %%
# first 15K data pieces for training
# iloc

X_train = X.iloc[0:15000]
y_train = y.iloc[0:15000]

# Rest for testing
X_test = X.iloc[15000:]
y_test = y.iloc[15000:]

# %%
X_train.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# population            0
# households            0
# median_income         0
# dtype: int64

# %%
X_train.shape
X_train.head()
# Out:
#   longitude latitude housing_median_age total_rooms population households  \
# 0   -122.23    37.88               41.0       880.0      322.0      126.0
# 1   -122.22    37.86               21.0      7099.0     2401.0     1138.0
# 2   -122.24    37.85               52.0      1467.0      496.0      177.0
# 3   -122.25    37.85               52.0      1274.0      558.0      219.0
# 4   -122.25    37.85               52.0      1627.0      565.0      259.0
#
#   median_income
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462

# %%
# fit the data in the model

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#SNAS: my input as below as I need to tweek a bit due to different dataset. Refer to sir's note

# check which features came to be the most important for the model
feature_importance =  pd.DataFrame({
#'Features': housing_data.feature_names, 
#'Features': ['MedInc',	'HouseAge',	'AveRooms'	,'Latitude'],
'Features': ['longitude', 'latitude', 'housing_median_age','total_rooms', 'population', 'households', 'median_income'],
'Model Coefficients': model.coef_
}).sort_values('Model Coefficients', ascending=False)
feature_importance

feature_importance
# how much weight was assigned to each feature

#SNAS: from the output it seems that median_income is the most important feature
# Out:
#              Features  Model Coefficients
# 6       median_income        38763.611645
# 2  housing_median_age          872.937256
# 5          households          160.369495
# 3         total_rooms           -2.373721
# 4          population          -47.602645
# 0           longitude       -34806.470011
# 1            latitude       -38658.528743

# %% [markdown]
# ## Step 6: Testing
#
# - Make predictions
# - Evaluation - Calculate the performance of the model

# %%
y_predict1 = model.predict(X_test)
y_predict1
# Out:
# array([228074.8882537 , 165239.26882879, 148934.6837209 , ...,
#         29216.57011369,  40177.94244361,  54258.286842  ], shape=(5640,))

# %%
# the model, does not know anything about these
y_test, X_test
# Out:
# (15000    140700.0
#  15001    119200.0
#  15002    132000.0
#  15003    144000.0
#  15004    142900.0
#             ...
#  20635     78100.0
#  20636     77100.0
#  20637     92300.0
#  20638     84700.0
#  20639     89400.0
#  Name: Price, Length: 5640, dtype: float64,
#        longitude latitude housing_median_age total_rooms population households  \
#  15000   -117.04    32.74               33.0      3880.0     2288.0      805.0
#  15001   -117.02    32.74               12.0      3301.0     2000.0      879.0
#  15002   -117.04    32.74                5.0      2878.0     1727.0      758.0
#  15003   -117.04    32.75               36.0      2297.0     1070.0      392.0
#  15004   -117.05    32.75               29.0      2767.0     1437.0      587.0
#  ...         ...      ...                ...         ...        ...        ...
#  20635   -121.09    39.48               25.0      1665.0      845.0      330.0
# ...

# %%
#SNAS: I've changed the data a bit so that satisfy the different dataset. Refer to sir's note

model.predict([[-122.23,	37.88,	41.0,	880.0,  322.0,	126.0,	8.3252],
               [-122.22,	37.86,	21.0,	7099.0, 2401.0,	1138.0,	8.3014],
               [-122.24,	37.85,	52.0,	1467.0, 496.0,	177.0,	7.2574],
               [-122.25,	37.85,	52.0,	1274.0, 558.0,	219.0,	5.6431],
               [-122.25,	37.85,	52.0,	1627.0, 565.0,	259.0,	3.8462],])
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([388694.86846394, 419304.51163949, 356915.82386379, 298930.07334184,
#        234519.37717093])

# %% [markdown]
# ##### Evaluation

# %%
# evaluation metrics
r2 = r2_score(y_test, t1)y_predic # 0.575

mae = mean_absolute_error(y_test, y_predict1) # 0.53
mae
# Out:
# 54098.632967918034
