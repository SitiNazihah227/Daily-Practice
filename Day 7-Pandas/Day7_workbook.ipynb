# %% [markdown]
# **02/12/2025** SNAS

# %% [markdown]
# **Task 1**
#
# - create one class
# - one attribute saves name
# - one method welcome(name): return f'Welcome {name}!!!"

# %%
class selamatdatang:

    def welcome(name):
        return (f'Welcome {name}')

name = input('Enter your name:\t')
print(selamatdatang.welcome(name))
# Out:
# Welcome Siti
